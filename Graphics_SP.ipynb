# %%
import random
import pandas as pd
import numpy as np
import seaborn as sns
from collections import deque
import matplotlib.pyplot as plt

# %% [markdown]
# Рез-ты эксперимента с sum pi > 40

# %%
exp_results_lower_big = {2: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 3: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 4: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 5: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 6: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 7: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 8: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 9: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 10: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 11: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 12: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 13: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 14: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 15: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 16: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 17: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 18: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 19: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 20: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 21: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 22: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 23: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 24: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 25: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 26: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 27: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 28: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 29: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 30: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 31: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 32: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 33: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 34: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 35: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 36: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 37: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 38: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 39: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 40: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 41: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 42: {'instances': 39, 'min_ratio': 0.6829871414441148, 'sum_ratio': 32.426144962803505}, 43: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 44: {'instances': 51, 'min_ratio': 0.6412621359223301, 'sum_ratio': 42.86340194653166}, 45: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 46: {'instances': 48, 'min_ratio': 0.640691114245416, 'sum_ratio': 39.010158585352514}, 47: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 48: {'instances': 50, 'min_ratio': 0.6568483063328424, 'sum_ratio': 41.93531907771292}, 49: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 50: {'instances': 52, 'min_ratio': 0.719718309859155, 'sum_ratio': 42.95865982261558}}
exp_results_upper_big = {2: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 3: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 4: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 5: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 6: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 7: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 8: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 9: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 10: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 11: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 12: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 13: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 14: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 15: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 16: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 17: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 18: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 19: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 20: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 21: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 22: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 23: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 24: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 25: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 26: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 27: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 28: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 29: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 30: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 31: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 32: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 33: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 34: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 35: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 36: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 37: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 38: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 39: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 40: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 41: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 42: {'instances': 39, 'max_ratio': 1.4378194207836457, 'sum_ratio': 42.27190608665013}, 43: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 44: {'instances': 51, 'max_ratio': 1.218172983479106, 'sum_ratio': 54.60758772307222}, 45: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 46: {'instances': 48, 'max_ratio': 1.2714200119832235, 'sum_ratio': 51.5661311032828}, 47: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 48: {'instances': 50, 'max_ratio': 1.3197596795727637, 'sum_ratio': 52.98896502337393}, 49: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 50: {'instances': 52, 'max_ratio': 1.4997239094422972, 'sum_ratio': 57.03822272672057}}

# %% [markdown]
# Рез-ты эксперимента с sum pi <= 40

# %%
exp_results_lower = {2: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 3: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 4: {'instances': 104, 'min_ratio': 1, 'sum_ratio': 104.0}, 5: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 6: {'instances': 201, 'min_ratio': 0.8538461538461538, 'sum_ratio': 200.36553290783456}, 7: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 8: {'instances': 226, 'min_ratio': 0.759493670886076, 'sum_ratio': 223.05730327476996}, 9: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 10: {'instances': 270, 'min_ratio': 0.7542372881355932, 'sum_ratio': 264.73911145651607}, 11: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 12: {'instances': 280, 'min_ratio': 0.7892156862745098, 'sum_ratio': 276.28183491666675}, 13: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 14: {'instances': 290, 'min_ratio': 0.7137931034482758, 'sum_ratio': 283.1768945147469}, 15: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 16: {'instances': 367, 'min_ratio': 0.6851063829787234, 'sum_ratio': 355.00669086658337}, 17: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 18: {'instances': 338, 'min_ratio': 0.6511226252158895, 'sum_ratio': 323.98415675773515}, 19: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 20: {'instances': 318, 'min_ratio': 0.6666666666666666, 'sum_ratio': 301.90126585291216}, 21: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 22: {'instances': 279, 'min_ratio': 0.6935146443514645, 'sum_ratio': 262.2211987718647}, 23: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 24: {'instances': 305, 'min_ratio': 0.6448275862068965, 'sum_ratio': 281.3243946742482}, 25: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 26: {'instances': 304, 'min_ratio': 0.5671191553544495, 'sum_ratio': 278.38609152932924}, 27: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 28: {'instances': 295, 'min_ratio': 0.6508746355685131, 'sum_ratio': 265.1026673704559}, 29: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 30: {'instances': 287, 'min_ratio': 0.637062937062937, 'sum_ratio': 254.3483217267969}, 31: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 32: {'instances': 240, 'min_ratio': 0.5343007915567283, 'sum_ratio': 207.56226550147224}, 33: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 34: {'instances': 252, 'min_ratio': 0.6437598736176935, 'sum_ratio': 218.20897743206646}, 35: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 36: {'instances': 263, 'min_ratio': 0.6463932107496464, 'sum_ratio': 229.05867899910675}, 37: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 38: {'instances': 271, 'min_ratio': 0.5835275835275835, 'sum_ratio': 229.064869210959}, 39: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 40: {'instances': 234, 'min_ratio': 0.5675965665236051, 'sum_ratio': 198.66120601695073}}
exp_results_upper = {2: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 3: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 4: {'instances': 104, 'max_ratio': 1.0, 'sum_ratio': 104.0}, 5: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 6: {'instances': 201, 'max_ratio': 1.375, 'sum_ratio': 210.05431665162294}, 7: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 8: {'instances': 226, 'max_ratio': 1.5, 'sum_ratio': 235.08352913414186}, 9: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 10: {'instances': 270, 'max_ratio': 1.5612903225806452, 'sum_ratio': 282.4360133261014}, 11: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 12: {'instances': 280, 'max_ratio': 1.6428571428571428, 'sum_ratio': 295.00741204286425}, 13: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 14: {'instances': 290, 'max_ratio': 1.6359223300970873, 'sum_ratio': 305.43000196084927}, 15: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 16: {'instances': 367, 'max_ratio': 1.618421052631579, 'sum_ratio': 391.0458939030337}, 17: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 18: {'instances': 338, 'max_ratio': 1.5511945392491469, 'sum_ratio': 358.6287934325202}, 19: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 20: {'instances': 318, 'max_ratio': 1.4879227053140096, 'sum_ratio': 335.95232822782145}, 21: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 22: {'instances': 279, 'max_ratio': 1.454726368159204, 'sum_ratio': 295.8239974021262}, 23: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 24: {'instances': 305, 'max_ratio': 1.5389344262295082, 'sum_ratio': 323.7334901839654}, 25: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 26: {'instances': 304, 'max_ratio': 1.5456674473067915, 'sum_ratio': 323.93953004642066}, 27: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 28: {'instances': 295, 'max_ratio': 1.5617597292724197, 'sum_ratio': 317.1307975614297}, 29: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 30: {'instances': 287, 'max_ratio': 1.4069767441860466, 'sum_ratio': 308.3359923886069}, 31: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 32: {'instances': 240, 'max_ratio': 1.4905405405405405, 'sum_ratio': 258.6097485467028}, 33: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 34: {'instances': 252, 'max_ratio': 1.5389876880984952, 'sum_ratio': 271.021496911972}, 35: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 36: {'instances': 263, 'max_ratio': 1.3953488372093024, 'sum_ratio': 283.2618062299147}, 37: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 38: {'instances': 271, 'max_ratio': 1.4543189368770764, 'sum_ratio': 291.8307380355709}, 39: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 40: {'instances': 234, 'max_ratio': 1.3359013867488443, 'sum_ratio': 251.07206757978938}}

# %%
exp_results_lower_big.update(exp_results_lower)
exp_results_upper_big.update(exp_results_upper)

exp_results_lower = exp_results_lower_big
exp_results_upper = exp_results_upper_big

# %%
[mean_values_upper[i] for i in range (max_sum_pi + 1) if i in sump_subset]
# Out:
# [1.0,
#  1.0450463515006116,
#  1.0401926067882383,
#  1.0460593086151904,
#  1.0535979001530866,
#  1.0532069033132734,
#  1.0655201468747513,
#  1.0610319332323082,
#  1.0564538623516397,
#  1.0603010659574417,
#  1.0614212792916897,
#  1.0655905593632258,
#  1.075019652750609,
#  1.0743414368941007,
#  1.077540618944595,
#  1.0754821306030635,
#  1.077041088326672,
#  1.0768661920131768,
#  1.0729575537597837,
#  1.0838950278628237,
#  1.0707370141778867,
#  1.0742943979850583,
#  1.0597793004674785,
#  1.09688889859078]

# %%
bound_instances = 0
max_sum_pi = 50
# exp_results_lower and exp_results_upper - it's output from algorithm in main.py

#exp_results_lower = {2: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 3: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 4: {'instances': 29, 'min_ratio': 1, 'sum_ratio': 29.0}, 5: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 6: {'instances': 41, 'min_ratio': 0.8397435897435898, 'sum_ratio': 40.73733395118937}, 7: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 8: {'instances': 38, 'min_ratio': 0.8366336633663366, 'sum_ratio': 37.64665921035935}, 9: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 10: {'instances': 58, 'min_ratio': 0.81875, 'sum_ratio': 56.98423865537213}, 11: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 12: {'instances': 41, 'min_ratio': 0.8711340206185567, 'sum_ratio': 40.550116889924965}, 13: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 14: {'instances': 62, 'min_ratio': 0.7853403141361257, 'sum_ratio': 60.61204520599634}, 15: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 16: {'instances': 63, 'min_ratio': 0.7625, 'sum_ratio': 61.253689555203415}, 17: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 18: {'instances': 66, 'min_ratio': 0.6958637469586375, 'sum_ratio': 62.355171550435934}, 19: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 20: {'instances': 73, 'min_ratio': 0.7008466603951082, 'sum_ratio': 68.67513193438784}, 21: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 22: {'instances': 48, 'min_ratio': 0.7577092511013216, 'sum_ratio': 44.38743710838488}, 23: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 24: {'instances': 46, 'min_ratio': 0.753731343283582, 'sum_ratio': 42.163916443882506}, 25: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 26: {'instances': 59, 'min_ratio': 0.723388848660391, 'sum_ratio': 54.05732062761935}, 27: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 28: {'instances': 45, 'min_ratio': 0.714759535655058, 'sum_ratio': 40.77061675333706}, 29: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 30: {'instances': 53, 'min_ratio': 0.7257174392935982, 'sum_ratio': 46.22488392861314}, 31: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 32: {'instances': 55, 'min_ratio': 0.6384615384615384, 'sum_ratio': 46.97783753683236}, 33: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 34: {'instances': 59, 'min_ratio': 0.653114186851211, 'sum_ratio': 51.02214061223713}, 35: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 36: {'instances': 59, 'min_ratio': 0.6726315789473685, 'sum_ratio': 49.69660066534417}, 37: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 38: {'instances': 39, 'min_ratio': 0.602204869085898, 'sum_ratio': 33.14652275737148}, 39: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 40: {'instances': 46, 'min_ratio': 0.5858343337334934, 'sum_ratio': 37.91882207073598}}
#{2: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 3: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 4: {'instances': 23, 'min_ratio': 1, 'sum_ratio': 23.0}, 5: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 6: {'instances': 28, 'min_ratio': 0.8636363636363636, 'sum_ratio': 27.863636363636363}, 7: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 8: {'instances': 53, 'min_ratio': 0.8, 'sum_ratio': 51.92315773923271}, 9: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 10: {'instances': 77, 'min_ratio': 0.76, 'sum_ratio': 74.5603766019876}, 11: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 12: {'instances': 97, 'min_ratio': 0.7384615384615385, 'sum_ratio': 94.51648986187662}, 13: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 14: {'instances': 148, 'min_ratio': 0.6761363636363636, 'sum_ratio': 140.2633393859997}, 15: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 16: {'instances': 135, 'min_ratio': 0.6818181818181818, 'sum_ratio': 130.25673497571742}, 17: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 18: {'instances': 136, 'min_ratio': 0.6592592592592592, 'sum_ratio': 128.2521069697919}, 19: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 20: {'instances': 137, 'min_ratio': 0.6188524590163934, 'sum_ratio': 127.5458161864003}, 21: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 22: {'instances': 149, 'min_ratio': 0.6481481481481481, 'sum_ratio': 136.4980534619585}, 23: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 24: {'instances': 135, 'min_ratio': 0.63671875, 'sum_ratio': 121.4900156919173}, 25: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 26: {'instances': 157, 'min_ratio': 0.5433673469387755, 'sum_ratio': 139.03602128431407}, 27: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 28: {'instances': 143, 'min_ratio': 0.6421052631578947, 'sum_ratio': 125.51357395883062}, 29: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 30: {'instances': 151, 'min_ratio': 0.5950920245398773, 'sum_ratio': 128.17159682105364}, 31: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 32: {'instances': 150, 'min_ratio': 0.5125925925925926, 'sum_ratio': 124.40354003169992}}

sump_subset = [i for i in range(2, max_sum_pi + 1) if exp_results_lower[i]['instances'] > bound_instances]
min_values_lower = [0 for i in range(max_sum_pi + 1)]
mean_values_lower = [0 for i in range(max_sum_pi + 1)]

for i in range(2, max_sum_pi + 1):
  if exp_results_lower[i]['instances'] == 0:
    continue
  min_values_lower[i] = exp_results_lower[i]['min_ratio']
  mean_values_lower[i] = exp_results_lower[i]['sum_ratio'] / exp_results_lower[i]['instances']

# %%
fig, ax = plt.subplots(figsize=(18,11))
ax.plot(sump_subset, [mean_values_lower[i] for i in range (max_sum_pi + 1) if i in sump_subset], label='Mean ratio lower bound')
ax.plot(sump_subset, [min_values_lower[i] for i in range (max_sum_pi + 1) if i in sump_subset], label='Min ratio lower bound')

ax.plot(sump_subset, [mean_values_upper[i] for i in range (max_sum_pi + 1) if i in sump_subset], label='Mean ratio upper bound')
ax.plot(sump_subset, [max_values_upper[i] for i in range (max_sum_pi + 1) if i in sump_subset], label='Max ratio upper bound')
ax.plot(sump_subset, [0.5 + 1 / (i/2 + 1) for i in sump_subset], linestyle = '--')
ax.plot(sump_subset, [1.5 - 1 / (i/2 + 1) for i in sump_subset], linestyle = '--')

ax.set_ylabel('Value', fontsize=16)
ax.set_xlabel('T', fontsize=16)
ax.set_title('Statistics of ratio', fontsize=18)
ax.set_xticks(range(0, max_sum_pi + 1, 2))
ax.set_yticks(np.arange(0.5, 1.8, 0.1))
ax.legend(loc='best', fontsize=15)
ax.grid(axis='y')
plt.show()

# %%
bound_instances = 0
#exp_results_upper = {2: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 3: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 4: {'instances': 29, 'max_ratio': 1.0, 'sum_ratio': 29.0}, 5: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 6: {'instances': 41, 'max_ratio': 1.3598130841121496, 'sum_ratio': 42.26950956316067}, 7: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 8: {'instances': 38, 'max_ratio': 1.3484848484848484, 'sum_ratio': 39.0534162070393}, 9: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 10: {'instances': 58, 'max_ratio': 1.5029411764705882, 'sum_ratio': 60.4491069271162}, 11: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 12: {'instances': 41, 'max_ratio': 1.4166666666666667, 'sum_ratio': 43.028332107252965}, 13: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 14: {'instances': 62, 'max_ratio': 1.421875, 'sum_ratio': 65.7913719671551}, 15: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 16: {'instances': 63, 'max_ratio': 1.3022113022113022, 'sum_ratio': 65.80713266796637}, 17: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 18: {'instances': 66, 'max_ratio': 1.4047619047619047, 'sum_ratio': 69.84221459549133}, 19: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 20: {'instances': 73, 'max_ratio': 1.2969543147208122, 'sum_ratio': 76.37209642150866}, 21: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 22: {'instances': 48, 'max_ratio': 1.2775665399239544, 'sum_ratio': 50.06620414986279}, 23: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 24: {'instances': 46, 'max_ratio': 1.4021084337349397, 'sum_ratio': 49.177303668928765}, 25: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 26: {'instances': 59, 'max_ratio': 1.2681564245810055, 'sum_ratio': 62.69344272066391}, 27: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 28: {'instances': 45, 'max_ratio': 1.3185053380782918, 'sum_ratio': 47.15508366112315}, 29: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 30: {'instances': 53, 'max_ratio': 1.4393732970027249, 'sum_ratio': 57.14605458208568}, 31: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 32: {'instances': 55, 'max_ratio': 1.352112676056338, 'sum_ratio': 59.93293172390379}, 33: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 34: {'instances': 59, 'max_ratio': 1.1957894736842105, 'sum_ratio': 62.82134681795198}, 35: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 36: {'instances': 59, 'max_ratio': 1.2705530642750373, 'sum_ratio': 62.93488349545542}, 37: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 38: {'instances': 39, 'max_ratio': 1.2592592592592593, 'sum_ratio': 41.986878786372664}, 39: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 40: {'instances': 46, 'max_ratio': 1.401060070671378, 'sum_ratio': 49.539827817806334}}
#{2: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 3: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 4: {'instances': 23, 'max_ratio': 1.0, 'sum_ratio': 23.0}, 5: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 6: {'instances': 28, 'max_ratio': 1.25, 'sum_ratio': 29.179152056414644}, 7: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 8: {'instances': 53, 'max_ratio': 1.4, 'sum_ratio': 55.789912639274945}, 9: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 10: {'instances': 77, 'max_ratio': 1.5, 'sum_ratio': 81.2986485291343}, 11: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 12: {'instances': 97, 'max_ratio': 1.6428571428571428, 'sum_ratio': 102.99489862294925}, 13: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 14: {'instances': 148, 'max_ratio': 1.625, 'sum_ratio': 160.577453870682}, 15: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 16: {'instances': 135, 'max_ratio': 1.7560975609756098, 'sum_ratio': 145.41749599225636}, 17: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 18: {'instances': 136, 'max_ratio': 1.75, 'sum_ratio': 147.40481549397958}, 19: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 20: {'instances': 137, 'max_ratio': 1.5845588235294117, 'sum_ratio': 152.92011812473805}, 21: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 22: {'instances': 149, 'max_ratio': 1.8285714285714285, 'sum_ratio': 159.93536842152517}, 23: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 24: {'instances': 135, 'max_ratio': 1.5037037037037038, 'sum_ratio': 147.02162868776077}, 25: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 26: {'instances': 157, 'max_ratio': 1.6176470588235294, 'sum_ratio': 173.343272149384}, 27: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 28: {'instances': 143, 'max_ratio': 1.471698113207547, 'sum_ratio': 159.21076270408932}, 29: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 30: {'instances': 151, 'max_ratio': 1.6720183486238531, 'sum_ratio': 168.9830451375146}, 31: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 32: {'instances': 150, 'max_ratio': 1.5159420289855072, 'sum_ratio': 168.04750732193878}}

sump_subset = [i for i in range(2, max_sum_pi + 1) if exp_results_upper[i]['instances'] > bound_instances]
max_values_upper = [0 for i in range(max_sum_pi + 1)]
mean_values_upper = [0 for i in range(max_sum_pi + 1)]

for i in range(2, max_sum_pi + 1):
  if exp_results_upper[i]['instances'] == 0:
    continue
  max_values_upper[i] = exp_results_upper[i]['max_ratio']
  mean_values_upper[i] = exp_results_upper[i]['sum_ratio'] / exp_results_upper[i]['instances']

# %%
bound_instances = 0
#wsrpt_results_lower = {2: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 3: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 4: {'instances': 18, 'min_ratio': 1, 'sum_ratio': 18.0}, 5: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 6: {'instances': 36, 'min_ratio': 0.9, 'sum_ratio': 35.85454545454545}, 7: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 8: {'instances': 46, 'min_ratio': 0.803030303030303, 'sum_ratio': 45.653030303030306}, 9: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 10: {'instances': 74, 'min_ratio': 0.7222222222222222, 'sum_ratio': 72.49509367912091}, 11: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 12: {'instances': 99, 'min_ratio': 0.7452830188679245, 'sum_ratio': 94.66674573193318}, 13: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 14: {'instances': 141, 'min_ratio': 0.5916666666666667, 'sum_ratio': 134.66679927549924}, 15: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 16: {'instances': 145, 'min_ratio': 0.6764705882352942, 'sum_ratio': 139.34705737145802}, 17: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 18: {'instances': 151, 'min_ratio': 0.6704545454545454, 'sum_ratio': 142.7993260074646}, 19: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 20: {'instances': 155, 'min_ratio': 0.7142857142857143, 'sum_ratio': 145.28647355054468}, 21: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 22: {'instances': 180, 'min_ratio': 0.6723549488054608, 'sum_ratio': 166.4015154177097}, 23: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 24: {'instances': 117, 'min_ratio': 0.6091954022988506, 'sum_ratio': 105.5699133522099}, 25: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 26: {'instances': 149, 'min_ratio': 0.5890736342042755, 'sum_ratio': 132.36912177745364}, 27: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 28: {'instances': 134, 'min_ratio': 0.5880281690140845, 'sum_ratio': 116.20872016507354}, 29: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 30: {'instances': 152, 'min_ratio': 0.5610766045548654, 'sum_ratio': 130.937862616831}, 31: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 32: {'instances': 113, 'min_ratio': 0.6457925636007827, 'sum_ratio': 94.28353210084603}}

sump_subset = [i for i in range(2, 33) if wsrpt_results_lower[i]['instances'] > bound_instances]
min_value_wsrpt_lower = [0 for i in range(33)]
mean_values_wsrpt_lower = [0 for i in range(33)]

for i in range(2, 33):
  if wsrpt_results_lower[i]['instances'] == 0:
    continue
  min_value_wsrpt_lower[i] = wsrpt_results_lower[i]['min_ratio']
  mean_values_wsrpt_lower[i] = wsrpt_results_lower[i]['sum_ratio'] / wsrpt_results_lower[i]['instances']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-33411644f49d> in <module>()
# ...

# %%
wsrpt_res_groups_min_lower = []
wsrpt_res_groups_mean_lower = []

for i in range(0, 10):
  cur_sum_instances = np.sum(exp_wsrpt_lower_result[j]['instances'] for j in range(max(i *50, 2), (i+1) * 50 + 1))
  cur_sum_ratio = np.sum(exp_wsrpt_lower_result[j]['sum_ratio'] for j in range(max(i *50, 2), (i+1) * 50 + 1))
  cur_mean_ratio = cur_sum_ratio / cur_sum_instances

  cur_min_ratio = min(exp_wsrpt_lower_result[j]['min_ratio'] for j in range(max(i *50, 2), (i+1) * 50 + 1))
  wsrpt_res_groups_min_lower.append(cur_min_ratio)
  wsrpt_res_groups_mean_lower.append(cur_mean_ratio)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   """
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.

# %%
wsrpt_res_groups_max_upper= []
wsrpt_res_groups_mean_upper = []
wsrpt_res_sum_instances = []

for i in range(0, 10):
  cur_sum_instances = np.sum(exp_wsrpt_upper_result[j]['instances'] for j in range(max(i *50, 2), (i+1) * 50 + 1))
  cur_sum_ratio = np.sum(exp_wsrpt_upper_result[j]['sum_ratio'] for j in range(max(i *50, 2), (i+1) * 50 + 1))
  cur_mean_ratio = cur_sum_ratio / cur_sum_instances

  cur_min_ratio = max(exp_wsrpt_upper_result[j]['max_ratio'] for j in range(max(i *50, 2), (i+1) * 50 + 1))
  wsrpt_res_groups_max_upper.append(cur_min_ratio)
  wsrpt_res_groups_mean_upper.append(cur_mean_ratio)
  wsrpt_res_sum_instances.append(cur_sum_instances)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   import sys

# %%
fig, ax = plt.subplots(figsize=(15,9))
ax.plot(50 * np.arange(1, 11), [wsrpt_res_groups_mean_lower[i] for i in range (10)], label='Mean ratio lower bound')
ax.plot(50 * np.arange(1, 11), [wsrpt_res_groups_min_lower[i] for i in range (10)], label='Min ratio lower bound')

ax.plot(50 * np.arange(1, 11), [wsrpt_res_groups_mean_upper[i] for i in range (10)], label='Mean ratio upper bound')
ax.plot(50 * np.arange(1, 11), [wsrpt_res_groups_max_upper[i] for i in range (10)], label='Max ratio upper bound')
ax.plot(50 * np.arange(1, 11), [0.5 + 1 / (i/2 + 1) for i in 50 * np.arange(1, 11)], linestyle = '--')
ax.plot(50 * np.arange(1, 11), [1.5 - 1 / (i/2 + 1) for i in 50 * np.arange(1, 11)], linestyle = '--')

ax.set_ylabel('Value', fontsize=16)
ax.set_xlabel('T', fontsize=16)
ax.set_title('Statistics of ratio to WSRPT', fontsize=18)
#ax.set_xticks(range(10), , minor=True)
ax.legend(loc='best', fontsize=15)
ax.grid(axis='y')
plt.show()

# %%
exp_wsrpt_upper_result = {2: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 3: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 4: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 5: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 6: {'instances': 4, 'max_ratio': 1.1470588235294117, 'sum_ratio': 4.147058823529411}, 7: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 8: {'instances': 3, 'max_ratio': 1.0, 'sum_ratio': 3.0}, 9: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 10: {'instances': 5, 'max_ratio': 1.3478260869565217, 'sum_ratio': 5.3478260869565215}, 11: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 12: {'instances': 10, 'max_ratio': 1.1518987341772151, 'sum_ratio': 10.26728334956183}, 13: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 14: {'instances': 5, 'max_ratio': 1.0, 'sum_ratio': 5.0}, 15: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 16: {'instances': 9, 'max_ratio': 1.16, 'sum_ratio': 9.27111111111111}, 17: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 18: {'instances': 18, 'max_ratio': 1.4155844155844155, 'sum_ratio': 18.529393708121248}, 19: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 20: {'instances': 19, 'max_ratio': 1.457516339869281, 'sum_ratio': 20.27624993876675}, 21: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 22: {'instances': 27, 'max_ratio': 1.6635514018691588, 'sum_ratio': 28.490244988957887}, 23: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 24: {'instances': 23, 'max_ratio': 1.5714285714285714, 'sum_ratio': 25.999847452455732}, 25: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 26: {'instances': 24, 'max_ratio': 1.4558823529411764, 'sum_ratio': 25.843129790658274}, 27: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 28: {'instances': 31, 'max_ratio': 2.0273972602739727, 'sum_ratio': 33.43383502300819}, 29: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 30: {'instances': 23, 'max_ratio': 1.6764705882352942, 'sum_ratio': 27.098990619936245}, 31: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 32: {'instances': 24, 'max_ratio': 1.6216216216216217, 'sum_ratio': 25.52381642592992}, 33: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 34: {'instances': 27, 'max_ratio': 1.6842105263157894, 'sum_ratio': 29.18134196988212}, 35: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 36: {'instances': 38, 'max_ratio': 1.423728813559322, 'sum_ratio': 40.35968155131133}, 37: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 38: {'instances': 38, 'max_ratio': 1.688212927756654, 'sum_ratio': 41.77997408141844}, 39: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 40: {'instances': 21, 'max_ratio': 1.7044334975369457, 'sum_ratio': 25.20338060844722}, 41: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 42: {'instances': 27, 'max_ratio': 1.5918367346938775, 'sum_ratio': 31.10050925212948}, 43: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 44: {'instances': 28, 'max_ratio': 1.4850746268656716, 'sum_ratio': 30.932909704006107}, 45: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 46: {'instances': 31, 'max_ratio': 1.3569405099150142, 'sum_ratio': 33.56621064646647}, 47: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 48: {'instances': 25, 'max_ratio': 1.6607142857142858, 'sum_ratio': 29.146525443640872}, 49: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 50: {'instances': 25, 'max_ratio': 1.422680412371134, 'sum_ratio': 27.248274463111148}, 51: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 52: {'instances': 25, 'max_ratio': 1.6365853658536584, 'sum_ratio': 28.91575302350904}, 53: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 54: {'instances': 36, 'max_ratio': 1.3488372093023255, 'sum_ratio': 39.65464984696026}, 55: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 56: {'instances': 34, 'max_ratio': 1.7513513513513514, 'sum_ratio': 36.661955092602916}, 57: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 58: {'instances': 32, 'max_ratio': 1.581180811808118, 'sum_ratio': 34.95606185808472}, 59: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 60: {'instances': 34, 'max_ratio': 1.5949367088607596, 'sum_ratio': 38.99489100278773}, 61: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 62: {'instances': 21, 'max_ratio': 1.4253731343283582, 'sum_ratio': 23.006466655215917}, 63: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 64: {'instances': 27, 'max_ratio': 1.6403508771929824, 'sum_ratio': 31.274635563429158}, 65: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 66: {'instances': 28, 'max_ratio': 1.3842538190364277, 'sum_ratio': 31.433170985810747}, 67: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 68: {'instances': 39, 'max_ratio': 1.6779661016949152, 'sum_ratio': 44.934437377558055}, 69: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 70: {'instances': 31, 'max_ratio': 1.3404907975460123, 'sum_ratio': 34.59973669631117}, 71: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 72: {'instances': 23, 'max_ratio': 1.4678217821782178, 'sum_ratio': 26.773175518397732}, 73: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 74: {'instances': 37, 'max_ratio': 1.6228571428571428, 'sum_ratio': 44.23074564602659}, 75: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 76: {'instances': 23, 'max_ratio': 1.7750238322211631, 'sum_ratio': 26.7291392558637}, 77: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 78: {'instances': 29, 'max_ratio': 1.531615925058548, 'sum_ratio': 32.99031135922189}, 79: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 80: {'instances': 28, 'max_ratio': 1.672358591248666, 'sum_ratio': 33.21300345711424}, 81: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 82: {'instances': 17, 'max_ratio': 1.2867132867132867, 'sum_ratio': 18.497238364164033}, 83: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 84: {'instances': 29, 'max_ratio': 1.5817307692307692, 'sum_ratio': 33.55135080967564}, 85: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 86: {'instances': 33, 'max_ratio': 1.7929078014184396, 'sum_ratio': 39.2316387509363}, 87: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 88: {'instances': 18, 'max_ratio': 1.551033591731266, 'sum_ratio': 21.196710238008166}, 89: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 90: {'instances': 24, 'max_ratio': 1.4384017758046614, 'sum_ratio': 27.10469155383092}, 91: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 92: {'instances': 23, 'max_ratio': 1.853606027987083, 'sum_ratio': 28.869301251769826}, 93: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 94: {'instances': 28, 'max_ratio': 1.5336700336700337, 'sum_ratio': 33.916616854446396}, 95: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 96: {'instances': 29, 'max_ratio': 1.7415730337078652, 'sum_ratio': 34.07947564815177}, 97: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 98: {'instances': 15, 'max_ratio': 1.4599627560521415, 'sum_ratio': 17.90402160442396}, 99: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 100: {'instances': 29, 'max_ratio': 1.5650140318054255, 'sum_ratio': 35.07084471723495}, 101: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 102: {'instances': 22, 'max_ratio': 1.4441489361702127, 'sum_ratio': 26.219062339906465}, 103: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 104: {'instances': 25, 'max_ratio': 1.5646853146853146, 'sum_ratio': 30.41013185132118}, 105: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 106: {'instances': 25, 'max_ratio': 1.4543039319872475, 'sum_ratio': 28.813520889414345}, 107: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 108: {'instances': 23, 'max_ratio': 1.502267573696145, 'sum_ratio': 27.044265641788062}, 109: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 110: {'instances': 22, 'max_ratio': 1.468629961587708, 'sum_ratio': 25.83457040654212}, 111: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 112: {'instances': 25, 'max_ratio': 1.5188311688311689, 'sum_ratio': 29.04148650485028}, 113: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 114: {'instances': 16, 'max_ratio': 1.3794266441821248, 'sum_ratio': 18.939130060174467}, 115: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 116: {'instances': 24, 'max_ratio': 1.5289634146341464, 'sum_ratio': 29.409636364137075}, 117: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 118: {'instances': 20, 'max_ratio': 1.498927498927499, 'sum_ratio': 24.23408861061412}, 119: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 120: {'instances': 22, 'max_ratio': 1.5711019661636945, 'sum_ratio': 26.31740244709578}, 121: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 122: {'instances': 20, 'max_ratio': 1.5656565656565657, 'sum_ratio': 22.604980694594506}, 123: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 124: {'instances': 20, 'max_ratio': 1.4610303830911493, 'sum_ratio': 24.800877359790793}, 125: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 126: {'instances': 19, 'max_ratio': 1.4643406875320677, 'sum_ratio': 22.835445062139126}, 127: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 128: {'instances': 24, 'max_ratio': 1.494041708043694, 'sum_ratio': 28.179541651910455}, 129: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 130: {'instances': 25, 'max_ratio': 1.7465850211964202, 'sum_ratio': 30.580867174196086}, 131: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 132: {'instances': 27, 'max_ratio': 1.452109464082098, 'sum_ratio': 32.025178268167096}, 133: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 134: {'instances': 34, 'max_ratio': 1.550453514739229, 'sum_ratio': 40.30504866706476}, 135: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 136: {'instances': 15, 'max_ratio': 1.419806243272336, 'sum_ratio': 18.39485155683777}, 137: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 138: {'instances': 17, 'max_ratio': 1.6031695721077655, 'sum_ratio': 20.08765713227025}, 139: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 140: {'instances': 24, 'max_ratio': 1.3783632286995515, 'sum_ratio': 28.48213982789048}, 141: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 142: {'instances': 27, 'max_ratio': 1.4370442391832765, 'sum_ratio': 31.620913818568372}, 143: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 144: {'instances': 22, 'max_ratio': 1.3227571115973742, 'sum_ratio': 26.04920021457998}, 145: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 146: {'instances': 20, 'max_ratio': 1.3981385729058946, 'sum_ratio': 23.975077425040837}, 147: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 148: {'instances': 29, 'max_ratio': 1.4357707509881423, 'sum_ratio': 35.139708789239755}, 149: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 150: {'instances': 25, 'max_ratio': 1.4944491887275833, 'sum_ratio': 29.66723358135274}, 151: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 152: {'instances': 16, 'max_ratio': 1.381596752368065, 'sum_ratio': 18.937871993638574}, 153: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 154: {'instances': 20, 'max_ratio': 1.5387158996968862, 'sum_ratio': 22.882878364240714}, 155: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 156: {'instances': 19, 'max_ratio': 1.545263157894737, 'sum_ratio': 22.601245906581426}, 157: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 158: {'instances': 25, 'max_ratio': 1.5503455083909181, 'sum_ratio': 29.74812488557871}, 159: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 160: {'instances': 19, 'max_ratio': 1.4787052810902896, 'sum_ratio': 22.83108180204721}, 161: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 162: {'instances': 31, 'max_ratio': 1.4890318806668617, 'sum_ratio': 37.35620915596338}, 163: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 164: {'instances': 24, 'max_ratio': 1.4877344877344878, 'sum_ratio': 29.123707511535223}, 165: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 166: {'instances': 18, 'max_ratio': 1.3345170454545454, 'sum_ratio': 21.267437050782654}, 167: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 168: {'instances': 24, 'max_ratio': 1.5272727272727273, 'sum_ratio': 29.17929767415572}, 169: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 170: {'instances': 14, 'max_ratio': 1.4039610185476266, 'sum_ratio': 16.743363259326628}, 171: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 172: {'instances': 26, 'max_ratio': 1.4049508092668994, 'sum_ratio': 30.5835382016616}, 173: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 174: {'instances': 29, 'max_ratio': 1.6376445086705202, 'sum_ratio': 35.25844357301042}, 175: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 176: {'instances': 21, 'max_ratio': 1.521772056039379, 'sum_ratio': 25.585222880074063}, 177: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 178: {'instances': 28, 'max_ratio': 1.494288681204569, 'sum_ratio': 33.54011510682616}, 179: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 180: {'instances': 27, 'max_ratio': 1.5919055649241147, 'sum_ratio': 32.40116525004791}, 181: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 182: {'instances': 27, 'max_ratio': 1.3944259315358982, 'sum_ratio': 32.832938449406406}, 183: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 184: {'instances': 26, 'max_ratio': 1.527592768791627, 'sum_ratio': 30.6436014071376}, 185: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 186: {'instances': 23, 'max_ratio': 1.5336296296296297, 'sum_ratio': 27.551732875399907}, 187: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 188: {'instances': 20, 'max_ratio': 1.5143132840141524, 'sum_ratio': 23.53883367716841}, 189: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 190: {'instances': 28, 'max_ratio': 1.4879415347137637, 'sum_ratio': 33.83432998042925}, 191: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 192: {'instances': 25, 'max_ratio': 1.3550592525068368, 'sum_ratio': 29.73166358824223}, 193: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 194: {'instances': 26, 'max_ratio': 1.4427416638598856, 'sum_ratio': 30.583467111723476}, 195: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 196: {'instances': 18, 'max_ratio': 1.5252704031465094, 'sum_ratio': 21.715064825737116}, 197: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 198: {'instances': 21, 'max_ratio': 1.4340934371523915, 'sum_ratio': 25.959301368639693}, 199: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 200: {'instances': 20, 'max_ratio': 1.4159597030752917, 'sum_ratio': 24.24813877559107}, 201: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 202: {'instances': 17, 'max_ratio': 1.3623514294892387, 'sum_ratio': 20.446866296673747}, 203: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 204: {'instances': 13, 'max_ratio': 1.5300030459945173, 'sum_ratio': 16.308084811846665}, 205: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 206: {'instances': 18, 'max_ratio': 1.5081644144144144, 'sum_ratio': 22.834139999903407}, 207: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 208: {'instances': 26, 'max_ratio': 1.5120538217155672, 'sum_ratio': 31.645888030376653}, 209: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 210: {'instances': 14, 'max_ratio': 1.4412460567823344, 'sum_ratio': 17.210590090286185}, 211: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 212: {'instances': 26, 'max_ratio': 1.4983948635634028, 'sum_ratio': 31.896895596638473}, 213: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 214: {'instances': 21, 'max_ratio': 1.4537629662326197, 'sum_ratio': 25.76004917651628}, 215: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 216: {'instances': 23, 'max_ratio': 1.4833815028901733, 'sum_ratio': 28.04396233703865}, 217: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 218: {'instances': 27, 'max_ratio': 1.396927374301676, 'sum_ratio': 32.46008946559489}, 219: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 220: {'instances': 18, 'max_ratio': 1.4559877175025588, 'sum_ratio': 22.008463016852517}, 221: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 222: {'instances': 21, 'max_ratio': 1.472568093385214, 'sum_ratio': 25.757924696640853}, 223: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 224: {'instances': 20, 'max_ratio': 1.4851926977687626, 'sum_ratio': 23.676062892573672}, 225: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 226: {'instances': 21, 'max_ratio': 1.34037558685446, 'sum_ratio': 25.326967086166572}, 227: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 228: {'instances': 25, 'max_ratio': 1.3989692935366116, 'sum_ratio': 30.056279064717486}, 229: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 230: {'instances': 21, 'max_ratio': 1.3729941959713212, 'sum_ratio': 25.354934632102662}, 231: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 232: {'instances': 16, 'max_ratio': 1.4531225296442687, 'sum_ratio': 19.367184274997967}, 233: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 234: {'instances': 21, 'max_ratio': 1.3748338502436863, 'sum_ratio': 26.140416171674374}, 235: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 236: {'instances': 22, 'max_ratio': 1.4894837476099427, 'sum_ratio': 26.721715261473438}, 237: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 238: {'instances': 25, 'max_ratio': 1.4946476360392507, 'sum_ratio': 30.558495234569463}, 239: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 240: {'instances': 27, 'max_ratio': 1.5564691656590084, 'sum_ratio': 34.295595526903604}, 241: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 242: {'instances': 20, 'max_ratio': 1.7613878658654778, 'sum_ratio': 25.548303516757123}, 243: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 244: {'instances': 22, 'max_ratio': 1.4319193117769209, 'sum_ratio': 26.481780012627254}, 245: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 246: {'instances': 20, 'max_ratio': 1.393641429039659, 'sum_ratio': 25.11921819143843}, 247: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 248: {'instances': 21, 'max_ratio': 1.4235207463785908, 'sum_ratio': 25.692613943538813}, 249: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 250: {'instances': 26, 'max_ratio': 1.628858875413451, 'sum_ratio': 31.892843980808237}, 251: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 252: {'instances': 29, 'max_ratio': 1.5006090133982948, 'sum_ratio': 36.193809734929076}, 253: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 254: {'instances': 24, 'max_ratio': 1.3798416434838434, 'sum_ratio': 28.73565395484954}, 255: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 256: {'instances': 12, 'max_ratio': 1.4467328013802028, 'sum_ratio': 14.768305999170424}, 257: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 258: {'instances': 21, 'max_ratio': 1.3385502471169688, 'sum_ratio': 26.00986904337595}, 259: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 260: {'instances': 18, 'max_ratio': 1.555374109263658, 'sum_ratio': 22.20880048079135}, 261: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 262: {'instances': 18, 'max_ratio': 1.4392367543534643, 'sum_ratio': 22.16375633730051}, 263: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 264: {'instances': 28, 'max_ratio': 1.540896159317212, 'sum_ratio': 34.95981746913225}, 265: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 266: {'instances': 22, 'max_ratio': 1.501626171800268, 'sum_ratio': 27.261738044629507}, 267: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 268: {'instances': 28, 'max_ratio': 1.4087617668356263, 'sum_ratio': 34.681554078157035}, 269: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 270: {'instances': 23, 'max_ratio': 1.4511826874685456, 'sum_ratio': 28.300321254003087}, 271: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 272: {'instances': 27, 'max_ratio': 1.479875283446712, 'sum_ratio': 33.3190992110331}, 273: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 274: {'instances': 29, 'max_ratio': 1.4498601677986416, 'sum_ratio': 35.10621023268262}, 275: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 276: {'instances': 15, 'max_ratio': 1.31311706629055, 'sum_ratio': 18.002886737149147}, 277: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 278: {'instances': 24, 'max_ratio': 1.386563231850117, 'sum_ratio': 28.85741814246893}, 279: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 280: {'instances': 26, 'max_ratio': 1.4273495019488955, 'sum_ratio': 31.773771701484335}, 281: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 282: {'instances': 16, 'max_ratio': 1.3660202463715088, 'sum_ratio': 19.65743731125337}, 283: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 284: {'instances': 26, 'max_ratio': 1.402102757389407, 'sum_ratio': 31.609815194265636}, 285: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 286: {'instances': 19, 'max_ratio': 1.408130081300813, 'sum_ratio': 22.78744298603186}, 287: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 288: {'instances': 25, 'max_ratio': 1.4599785119527262, 'sum_ratio': 30.920542656367072}, 289: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 290: {'instances': 27, 'max_ratio': 1.472591857000993, 'sum_ratio': 33.33294469346859}, 291: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 292: {'instances': 21, 'max_ratio': 1.3942541795163124, 'sum_ratio': 26.0294641827565}, 293: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 294: {'instances': 20, 'max_ratio': 1.5032841739992564, 'sum_ratio': 25.395931281966323}, 295: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 296: {'instances': 21, 'max_ratio': 1.4133289014459032, 'sum_ratio': 25.327070493136834}, 297: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 298: {'instances': 20, 'max_ratio': 1.5611328574717938, 'sum_ratio': 24.37174163195829}, 299: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 300: {'instances': 18, 'max_ratio': 1.434052757793765, 'sum_ratio': 22.259682760259885}, 301: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 302: {'instances': 20, 'max_ratio': 1.3583879342316727, 'sum_ratio': 24.182577401392788}, 303: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 304: {'instances': 20, 'max_ratio': 1.3407574901074053, 'sum_ratio': 24.440173336697537}, 305: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 306: {'instances': 27, 'max_ratio': 1.4545454545454546, 'sum_ratio': 33.531203832555526}, 307: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 308: {'instances': 24, 'max_ratio': 1.418552036199095, 'sum_ratio': 29.568178365376003}, 309: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 310: {'instances': 20, 'max_ratio': 1.416832961615213, 'sum_ratio': 24.537230923245843}, 311: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 312: {'instances': 18, 'max_ratio': 1.4257715213860314, 'sum_ratio': 22.490774027872295}, 313: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 314: {'instances': 28, 'max_ratio': 1.3412447923242015, 'sum_ratio': 34.14371789581279}, 315: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 316: {'instances': 18, 'max_ratio': 1.3402676560222606, 'sum_ratio': 21.800432167066365}, 317: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 318: {'instances': 22, 'max_ratio': 1.382246879334258, 'sum_ratio': 27.01223285774598}, 319: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 320: {'instances': 15, 'max_ratio': 1.5082671247584283, 'sum_ratio': 18.104880827423045}, 321: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 322: {'instances': 24, 'max_ratio': 1.5427103403982017, 'sum_ratio': 29.83482988779232}, 323: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 324: {'instances': 20, 'max_ratio': 1.3867146498725447, 'sum_ratio': 24.618819858163608}, 325: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 326: {'instances': 25, 'max_ratio': 1.375759742581337, 'sum_ratio': 30.66239105975323}, 327: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 328: {'instances': 21, 'max_ratio': 1.4221134704711347, 'sum_ratio': 26.219474864767278}, 329: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 330: {'instances': 19, 'max_ratio': 1.345509038119322, 'sum_ratio': 23.31643857900386}, 331: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 332: {'instances': 17, 'max_ratio': 1.363777966581705, 'sum_ratio': 20.755437979723986}, 333: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 334: {'instances': 15, 'max_ratio': 1.4542413700829542, 'sum_ratio': 18.639573270051354}, 335: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 336: {'instances': 11, 'max_ratio': 1.3848159509202453, 'sum_ratio': 13.458265816312075}, 337: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 338: {'instances': 15, 'max_ratio': 1.3599092069797134, 'sum_ratio': 17.871750143715975}, 339: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 340: {'instances': 20, 'max_ratio': 1.4379972977030475, 'sum_ratio': 24.62357048420398}, 341: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 342: {'instances': 19, 'max_ratio': 1.4073791994584073, 'sum_ratio': 22.692176967639387}, 343: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 344: {'instances': 24, 'max_ratio': 1.5071428571428571, 'sum_ratio': 28.92256112920674}, 345: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 346: {'instances': 17, 'max_ratio': 1.343884241465069, 'sum_ratio': 20.677714089731904}, 347: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 348: {'instances': 18, 'max_ratio': 1.3885108086469176, 'sum_ratio': 21.875804006868243}, 349: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 350: {'instances': 18, 'max_ratio': 1.3765994814752864, 'sum_ratio': 22.462775124981935}, 351: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 352: {'instances': 15, 'max_ratio': 1.2771269773407439, 'sum_ratio': 17.914059808726158}, 353: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 354: {'instances': 16, 'max_ratio': 1.4262014342288345, 'sum_ratio': 19.648053888261483}, 355: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 356: {'instances': 18, 'max_ratio': 1.4529411764705882, 'sum_ratio': 22.503511114883914}, 357: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 358: {'instances': 19, 'max_ratio': 1.5100765068109723, 'sum_ratio': 24.066227601129107}, 359: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 360: {'instances': 10, 'max_ratio': 1.3623628526645768, 'sum_ratio': 12.594156554065087}, 361: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 362: {'instances': 14, 'max_ratio': 1.4395541583309517, 'sum_ratio': 18.047208340082292}, 363: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 364: {'instances': 11, 'max_ratio': 1.360581674431738, 'sum_ratio': 13.270582713159707}, 365: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 366: {'instances': 11, 'max_ratio': 1.326448292649002, 'sum_ratio': 13.64846076633367}, 367: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 368: {'instances': 15, 'max_ratio': 1.393310378750615, 'sum_ratio': 18.459807377285053}, 369: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 370: {'instances': 14, 'max_ratio': 1.341500158579131, 'sum_ratio': 17.481213616263314}, 371: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 372: {'instances': 17, 'max_ratio': 1.346742643306685, 'sum_ratio': 20.774508669113228}, 373: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 374: {'instances': 19, 'max_ratio': 1.3717636445647272, 'sum_ratio': 23.230281168493264}, 375: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 376: {'instances': 21, 'max_ratio': 1.3624858524539563, 'sum_ratio': 25.684362777324097}, 377: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 378: {'instances': 21, 'max_ratio': 1.362685591558502, 'sum_ratio': 25.264496460906443}, 379: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 380: {'instances': 12, 'max_ratio': 1.4226837844468068, 'sum_ratio': 14.376945566489715}, 381: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 382: {'instances': 12, 'max_ratio': 1.3624336646984079, 'sum_ratio': 14.74275053782885}, 383: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 384: {'instances': 15, 'max_ratio': 1.3117151058485828, 'sum_ratio': 18.50239242788965}, 385: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 386: {'instances': 11, 'max_ratio': 1.3564343845371312, 'sum_ratio': 13.5211443540425}, 387: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 388: {'instances': 14, 'max_ratio': 1.3001740860482467, 'sum_ratio': 16.581014763938988}, 389: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 390: {'instances': 8, 'max_ratio': 1.3888687891944043, 'sum_ratio': 9.61567626084891}, 391: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 392: {'instances': 14, 'max_ratio': 1.2721694036300777, 'sum_ratio': 16.653046029804504}, 393: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 394: {'instances': 10, 'max_ratio': 1.2759850818874656, 'sum_ratio': 12.036099701232649}, 395: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 396: {'instances': 17, 'max_ratio': 1.2960127349909036, 'sum_ratio': 20.471752515675302}, 397: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 398: {'instances': 10, 'max_ratio': 1.2710301227222016, 'sum_ratio': 12.03762813497094}, 399: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 400: {'instances': 8, 'max_ratio': 1.3737618147448014, 'sum_ratio': 9.685871751858729}, 401: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 402: {'instances': 14, 'max_ratio': 1.3082437275985663, 'sum_ratio': 16.754278633498352}, 403: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 404: {'instances': 12, 'max_ratio': 1.2495370370370371, 'sum_ratio': 14.307780140796824}, 405: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 406: {'instances': 8, 'max_ratio': 1.3030704488778055, 'sum_ratio': 9.61403211000996}, 407: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 408: {'instances': 8, 'max_ratio': 1.2321686996071946, 'sum_ratio': 9.484679638335743}, 409: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 410: {'instances': 10, 'max_ratio': 1.336600566572238, 'sum_ratio': 11.792963676370258}, 411: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 412: {'instances': 11, 'max_ratio': 1.2888287845258586, 'sum_ratio': 13.4795808358141}, 413: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 414: {'instances': 6, 'max_ratio': 1.3233435638201843, 'sum_ratio': 7.141497327406828}, 415: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 416: {'instances': 4, 'max_ratio': 1.2159177135148806, 'sum_ratio': 4.747667113422274}, 417: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 418: {'instances': 9, 'max_ratio': 1.3136834830684174, 'sum_ratio': 11.07227784149143}, 419: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 420: {'instances': 10, 'max_ratio': 1.2911444933189475, 'sum_ratio': 11.71646521208982}, 421: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 422: {'instances': 4, 'max_ratio': 1.2655259822560203, 'sum_ratio': 4.858754104405044}, 423: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 424: {'instances': 4, 'max_ratio': 1.250859544123265, 'sum_ratio': 4.881819897010395}, 425: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 426: {'instances': 4, 'max_ratio': 1.2006090894893018, 'sum_ratio': 4.623978093314538}, 427: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 428: {'instances': 7, 'max_ratio': 1.250627784528149, 'sum_ratio': 8.51955566288225}, 429: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 430: {'instances': 5, 'max_ratio': 1.2464951846885286, 'sum_ratio': 5.9570293065585}, 431: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 432: {'instances': 2, 'max_ratio': 1.2543798177995795, 'sum_ratio': 2.4720727353471483}, 433: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 434: {'instances': 9, 'max_ratio': 1.2783648945872002, 'sum_ratio': 10.742681619233155}, 435: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 436: {'instances': 4, 'max_ratio': 1.2071219812336564, 'sum_ratio': 4.620193833857419}, 437: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 438: {'instances': 4, 'max_ratio': 1.2000215889464594, 'sum_ratio': 4.668098935909048}, 439: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 440: {'instances': 3, 'max_ratio': 1.211382645060115, 'sum_ratio': 3.477401238898648}, 441: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 442: {'instances': 7, 'max_ratio': 1.3232355993772704, 'sum_ratio': 8.419102726207052}, 443: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 444: {'instances': 6, 'max_ratio': 1.2772437822900395, 'sum_ratio': 7.0860642687595}, 445: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 446: {'instances': 4, 'max_ratio': 1.2877306646613063, 'sum_ratio': 4.693477087784328}, 447: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 448: {'instances': 3, 'max_ratio': 1.21285140562249, 'sum_ratio': 3.4606947718165406}, 449: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 450: {'instances': 5, 'max_ratio': 1.3036584045892412, 'sum_ratio': 5.945551590003527}, 451: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 452: {'instances': 2, 'max_ratio': 1.239212978943735, 'sum_ratio': 2.4578351357102215}, 453: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 454: {'instances': 1, 'max_ratio': 1.1125019558754499, 'sum_ratio': 1.1125019558754499}, 455: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 456: {'instances': 2, 'max_ratio': 1.225795843199158, 'sum_ratio': 2.344277623181248}, 457: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 458: {'instances': 2, 'max_ratio': 1.1468338730793082, 'sum_ratio': 2.2541589759599665}, 459: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 460: {'instances': 4, 'max_ratio': 1.3053460514640638, 'sum_ratio': 4.738765413896835}, 461: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 462: {'instances': 3, 'max_ratio': 1.2038847223392601, 'sum_ratio': 3.375494508138705}, 463: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 464: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 465: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 466: {'instances': 3, 'max_ratio': 1.3154817203125855, 'sum_ratio': 3.715247899027097}, 467: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 468: {'instances': 1, 'max_ratio': 1.1196297831192155, 'sum_ratio': 1.1196297831192155}, 469: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 470: {'instances': 1, 'max_ratio': 1.183011301494714, 'sum_ratio': 1.183011301494714}, 471: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 472: {'instances': 2, 'max_ratio': 1.1795132452311188, 'sum_ratio': 2.2885732591339534}, 473: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 474: {'instances': 1, 'max_ratio': 1.1858394960284853, 'sum_ratio': 1.1858394960284853}, 475: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 476: {'instances': 2, 'max_ratio': 1.2047790682151915, 'sum_ratio': 2.3985705088420755}, 477: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 478: {'instances': 2, 'max_ratio': 1.1401293501693872, 'sum_ratio': 2.220397531564303}, 479: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 480: {'instances': 2, 'max_ratio': 1.1314029595902106, 'sum_ratio': 2.2379884604203157}, 481: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 482: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 483: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 484: {'instances': 2, 'max_ratio': 1.181845238095238, 'sum_ratio': 2.3096109473236552}, 485: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 486: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 487: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 488: {'instances': 1, 'max_ratio': 1.0955015286067842, 'sum_ratio': 1.0955015286067842}, 489: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 490: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 491: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 492: {'instances': 1, 'max_ratio': 1.1763886657025016, 'sum_ratio': 1.1763886657025016}, 493: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 494: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 495: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 496: {'instances': 1, 'max_ratio': 1.1841708163573261, 'sum_ratio': 1.1841708163573261}, 497: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 498: {'instances': 1, 'max_ratio': 1.0714620902326204, 'sum_ratio': 1.0714620902326204}, 499: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 500: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 501: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 502: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 503: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 504: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 505: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 506: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 507: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 508: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 509: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 510: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 511: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 512: {'instances': 1, 'max_ratio': 1.2021485573971762, 'sum_ratio': 1.2021485573971762}, 513: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 514: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 515: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 516: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 517: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 518: {'instances': 2, 'max_ratio': 1.2331581688207167, 'sum_ratio': 2.3003708735850035}, 519: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 520: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 521: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 522: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 523: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 524: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 525: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 526: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 527: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 528: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 529: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 530: {'instances': 1, 'max_ratio': 1.1339000515198352, 'sum_ratio': 1.1339000515198352}, 531: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 532: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 533: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 534: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 535: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 536: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 537: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 538: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 539: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 540: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 541: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 542: {'instances': 1, 'max_ratio': 1.1511660447761194, 'sum_ratio': 1.1511660447761194}, 543: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 544: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 545: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 546: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 547: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 548: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 549: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 550: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 551: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 552: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 553: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 554: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 555: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 556: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 557: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 558: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 559: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 560: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 561: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 562: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 563: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 564: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 565: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 566: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 567: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 568: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 569: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 570: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 571: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 572: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 573: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 574: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 575: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 576: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 577: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 578: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 579: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 580: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 581: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 582: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 583: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 584: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 585: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 586: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 587: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 588: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 589: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 590: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 591: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 592: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 593: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 594: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 595: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 596: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 597: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 598: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 599: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 600: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 601: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 602: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 603: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 604: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 605: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 606: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 607: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 608: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 609: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 610: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 611: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 612: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 613: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 614: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 615: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 616: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 617: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 618: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 619: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 620: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 621: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 622: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 623: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 624: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 625: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 626: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 627: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 628: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 629: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 630: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 631: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 632: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 633: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 634: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 635: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 636: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 637: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 638: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 639: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 640: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 641: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 642: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 643: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 644: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 645: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 646: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 647: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 648: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 649: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 650: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 651: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 652: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 653: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 654: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 655: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 656: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 657: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 658: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 659: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 660: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 661: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 662: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 663: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 664: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 665: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 666: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 667: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 668: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 669: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 670: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 671: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 672: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 673: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 674: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 675: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 676: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 677: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 678: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 679: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 680: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 681: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 682: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 683: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 684: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 685: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 686: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 687: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 688: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 689: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 690: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 691: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 692: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 693: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 694: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 695: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 696: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 697: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 698: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 699: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 700: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 701: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 702: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 703: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 704: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 705: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 706: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 707: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 708: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 709: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 710: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 711: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 712: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 713: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 714: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 715: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 716: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 717: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 718: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 719: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 720: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 721: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 722: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 723: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 724: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 725: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 726: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 727: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 728: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 729: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 730: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 731: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 732: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 733: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 734: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 735: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 736: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 737: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 738: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 739: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 740: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 741: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 742: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 743: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 744: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 745: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 746: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 747: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 748: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 749: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 750: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 751: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 752: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 753: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 754: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 755: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 756: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 757: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 758: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 759: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 760: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 761: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 762: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 763: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 764: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 765: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 766: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 767: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 768: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 769: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 770: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 771: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 772: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 773: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 774: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 775: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 776: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 777: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 778: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 779: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 780: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 781: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 782: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 783: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 784: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 785: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 786: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 787: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 788: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 789: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 790: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 791: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 792: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 793: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 794: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 795: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 796: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 797: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 798: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 799: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 800: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 801: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 802: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 803: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 804: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 805: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 806: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 807: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 808: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 809: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 810: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 811: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 812: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 813: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 814: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 815: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 816: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 817: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 818: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 819: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 820: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 821: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 822: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 823: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 824: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 825: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 826: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 827: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 828: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 829: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 830: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 831: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 832: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 833: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 834: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 835: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 836: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 837: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 838: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 839: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 840: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 841: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 842: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 843: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 844: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 845: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 846: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 847: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 848: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 849: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 850: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 851: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 852: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 853: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 854: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 855: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 856: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 857: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 858: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 859: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 860: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 861: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 862: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 863: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 864: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 865: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 866: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 867: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 868: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 869: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 870: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 871: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 872: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 873: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 874: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 875: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 876: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 877: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 878: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 879: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 880: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 881: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 882: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 883: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 884: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 885: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 886: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 887: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 888: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 889: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 890: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 891: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 892: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 893: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 894: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 895: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 896: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 897: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 898: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 899: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 900: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 901: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 902: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 903: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 904: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 905: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 906: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 907: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 908: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 909: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 910: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 911: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 912: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 913: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 914: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 915: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 916: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 917: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 918: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 919: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 920: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 921: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 922: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 923: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 924: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 925: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 926: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 927: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 928: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 929: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 930: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 931: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 932: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 933: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 934: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 935: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 936: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 937: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 938: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 939: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 940: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 941: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 942: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 943: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 944: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 945: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 946: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 947: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 948: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 949: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 950: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 951: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 952: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 953: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 954: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 955: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 956: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 957: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 958: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 959: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 960: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 961: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 962: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 963: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 964: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 965: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 966: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 967: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 968: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 969: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 970: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 971: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 972: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 973: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 974: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 975: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 976: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 977: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 978: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 979: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 980: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 981: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 982: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 983: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 984: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 985: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 986: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 987: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 988: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 989: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 990: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 991: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 992: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 993: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 994: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 995: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 996: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 997: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 998: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 999: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}, 1000: {'instances': 0, 'max_ratio': 0, 'sum_ratio': 0}}

# %%
exp_wsrpt_lower_result = {2: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 3: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 4: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 5: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 6: {'instances': 4, 'min_ratio': 0.925, 'sum_ratio': 3.925}, 7: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 8: {'instances': 3, 'min_ratio': 0.875, 'sum_ratio': 2.875}, 9: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 10: {'instances': 5, 'min_ratio': 1, 'sum_ratio': 5.0}, 11: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 12: {'instances': 10, 'min_ratio': 0.8333333333333334, 'sum_ratio': 9.426795646336785}, 13: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 14: {'instances': 5, 'min_ratio': 1, 'sum_ratio': 5.0}, 15: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 16: {'instances': 9, 'min_ratio': 1, 'sum_ratio': 9.0}, 17: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 18: {'instances': 18, 'min_ratio': 0.6901408450704225, 'sum_ratio': 17.333781195947616}, 19: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 20: {'instances': 19, 'min_ratio': 0.8269230769230769, 'sum_ratio': 18.689668174962293}, 21: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 22: {'instances': 27, 'min_ratio': 0.7545454545454545, 'sum_ratio': 26.50886345293125}, 23: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 24: {'instances': 23, 'min_ratio': 0.6741071428571429, 'sum_ratio': 21.733688247501885}, 25: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 26: {'instances': 24, 'min_ratio': 0.8028169014084507, 'sum_ratio': 23.449233951273776}, 27: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 28: {'instances': 31, 'min_ratio': 0.7162790697674418, 'sum_ratio': 29.657220319591566}, 29: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 30: {'instances': 23, 'min_ratio': 0.5707317073170731, 'sum_ratio': 21.878511520450395}, 31: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 32: {'instances': 24, 'min_ratio': 0.6835443037974683, 'sum_ratio': 22.76939675126567}, 33: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 34: {'instances': 27, 'min_ratio': 0.7453580901856764, 'sum_ratio': 25.75773039980382}, 35: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 36: {'instances': 38, 'min_ratio': 0.6183206106870229, 'sum_ratio': 36.189981209907494}, 37: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 38: {'instances': 38, 'min_ratio': 0.546583850931677, 'sum_ratio': 35.039623714864746}, 39: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 40: {'instances': 21, 'min_ratio': 0.7765273311897106, 'sum_ratio': 19.661088175684384}, 41: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 42: {'instances': 27, 'min_ratio': 0.7309027777777778, 'sum_ratio': 24.591681256440147}, 43: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 44: {'instances': 28, 'min_ratio': 0.5705128205128205, 'sum_ratio': 24.649373611866878}, 45: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 46: {'instances': 31, 'min_ratio': 0.7635135135135135, 'sum_ratio': 28.592368550518223}, 47: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 48: {'instances': 25, 'min_ratio': 0.7019230769230769, 'sum_ratio': 22.957253528871767}, 49: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 50: {'instances': 25, 'min_ratio': 0.7444633730834753, 'sum_ratio': 22.481584193601602}, 51: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 52: {'instances': 25, 'min_ratio': 0.6691176470588235, 'sum_ratio': 22.499979569695952}, 53: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 54: {'instances': 36, 'min_ratio': 0.6481481481481481, 'sum_ratio': 31.54173871463173}, 55: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 56: {'instances': 34, 'min_ratio': 0.538860103626943, 'sum_ratio': 28.434466776502013}, 57: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 58: {'instances': 32, 'min_ratio': 0.6229508196721312, 'sum_ratio': 27.203721702347394}, 59: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 60: {'instances': 34, 'min_ratio': 0.7024647887323944, 'sum_ratio': 29.201560102120435}, 61: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 62: {'instances': 21, 'min_ratio': 0.6453287197231834, 'sum_ratio': 17.700027604550737}, 63: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 64: {'instances': 27, 'min_ratio': 0.6053639846743295, 'sum_ratio': 22.80043925937433}, 65: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 66: {'instances': 28, 'min_ratio': 0.6063291139240506, 'sum_ratio': 23.71264313405787}, 67: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 68: {'instances': 39, 'min_ratio': 0.5100830367734283, 'sum_ratio': 31.869977877820173}, 69: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 70: {'instances': 31, 'min_ratio': 0.5333876221498371, 'sum_ratio': 24.566958533269496}, 71: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 72: {'instances': 23, 'min_ratio': 0.6156968876860622, 'sum_ratio': 18.65724441489831}, 73: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 74: {'instances': 37, 'min_ratio': 0.48674080410607357, 'sum_ratio': 28.169285715190867}, 75: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 76: {'instances': 23, 'min_ratio': 0.6462035541195477, 'sum_ratio': 18.343803227789245}, 77: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 78: {'instances': 29, 'min_ratio': 0.5772058823529411, 'sum_ratio': 22.36359759724841}, 79: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 80: {'instances': 28, 'min_ratio': 0.5581929555895865, 'sum_ratio': 20.819452935112942}, 81: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 82: {'instances': 17, 'min_ratio': 0.576530612244898, 'sum_ratio': 12.264376587746984}, 83: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 84: {'instances': 29, 'min_ratio': 0.4885222381635581, 'sum_ratio': 20.578569793802103}, 85: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 86: {'instances': 33, 'min_ratio': 0.5309187279151943, 'sum_ratio': 23.17525645225593}, 87: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 88: {'instances': 18, 'min_ratio': 0.5906593406593407, 'sum_ratio': 12.744746759688129}, 89: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 90: {'instances': 24, 'min_ratio': 0.5654761904761905, 'sum_ratio': 17.311939987197402}, 91: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 92: {'instances': 23, 'min_ratio': 0.5220213259156236, 'sum_ratio': 15.059562136774698}, 93: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 94: {'instances': 28, 'min_ratio': 0.4093765103914935, 'sum_ratio': 18.691242149713414}, 95: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 96: {'instances': 29, 'min_ratio': 0.4716981132075472, 'sum_ratio': 19.604034900247413}, 97: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 98: {'instances': 15, 'min_ratio': 0.561282932416953, 'sum_ratio': 10.319646270065219}, 99: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 100: {'instances': 29, 'min_ratio': 0.500351370344343, 'sum_ratio': 19.292949679795175}, 101: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 102: {'instances': 22, 'min_ratio': 0.4186965108624095, 'sum_ratio': 14.515053687287445}, 103: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 104: {'instances': 25, 'min_ratio': 0.46210141139571353, 'sum_ratio': 16.283809589337178}, 105: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 106: {'instances': 25, 'min_ratio': 0.434643995749203, 'sum_ratio': 15.759908529965545}, 107: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 108: {'instances': 23, 'min_ratio': 0.430019305019305, 'sum_ratio': 14.42472300119571}, 109: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 110: {'instances': 22, 'min_ratio': 0.4801007556675063, 'sum_ratio': 14.087421025496536}, 111: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 112: {'instances': 25, 'min_ratio': 0.49503311258278143, 'sum_ratio': 15.639971875552952}, 113: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 114: {'instances': 16, 'min_ratio': 0.5174985656913368, 'sum_ratio': 9.598378238859116}, 115: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 116: {'instances': 24, 'min_ratio': 0.48158011540168666, 'sum_ratio': 14.876950188849646}, 117: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 118: {'instances': 20, 'min_ratio': 0.44754901960784316, 'sum_ratio': 12.278488259957555}, 119: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 120: {'instances': 22, 'min_ratio': 0.49144254278728605, 'sum_ratio': 13.721345339498306}, 121: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 122: {'instances': 20, 'min_ratio': 0.49597989949748744, 'sum_ratio': 12.274146741011531}, 123: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 124: {'instances': 20, 'min_ratio': 0.4892578125, 'sum_ratio': 11.82229513930487}, 125: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 126: {'instances': 19, 'min_ratio': 0.4497835497835498, 'sum_ratio': 10.821342959843868}, 127: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 128: {'instances': 24, 'min_ratio': 0.45148026315789475, 'sum_ratio': 14.86628032875829}, 129: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 130: {'instances': 25, 'min_ratio': 0.4305364511691884, 'sum_ratio': 14.785236689944973}, 131: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 132: {'instances': 27, 'min_ratio': 0.4898580121703854, 'sum_ratio': 15.649216272936144}, 133: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 134: {'instances': 34, 'min_ratio': 0.39466421343146274, 'sum_ratio': 19.362979510568735}, 135: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 136: {'instances': 15, 'min_ratio': 0.4671189979123173, 'sum_ratio': 8.258915610028772}, 137: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 138: {'instances': 17, 'min_ratio': 0.4649122807017544, 'sum_ratio': 9.808340118894742}, 139: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 140: {'instances': 24, 'min_ratio': 0.4220737913486005, 'sum_ratio': 13.168926922770959}, 141: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 142: {'instances': 27, 'min_ratio': 0.42602230483271375, 'sum_ratio': 15.078899917543906}, 143: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 144: {'instances': 22, 'min_ratio': 0.43746071653048396, 'sum_ratio': 12.350820538641274}, 145: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 146: {'instances': 20, 'min_ratio': 0.395748987854251, 'sum_ratio': 10.365348546284913}, 147: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 148: {'instances': 29, 'min_ratio': 0.4397233201581028, 'sum_ratio': 15.39685814482294}, 149: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 150: {'instances': 25, 'min_ratio': 0.43107932379713915, 'sum_ratio': 13.216584498023554}, 151: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 152: {'instances': 16, 'min_ratio': 0.3980385525870815, 'sum_ratio': 8.413752769965273}, 153: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 154: {'instances': 20, 'min_ratio': 0.4300327332242226, 'sum_ratio': 10.70417496475124}, 155: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 156: {'instances': 19, 'min_ratio': 0.4525631216526396, 'sum_ratio': 10.310615501666867}, 157: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 158: {'instances': 25, 'min_ratio': 0.3766349583828775, 'sum_ratio': 13.142351482622127}, 159: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 160: {'instances': 19, 'min_ratio': 0.38117489986648867, 'sum_ratio': 9.825308856753075}, 161: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 162: {'instances': 31, 'min_ratio': 0.4287245444801715, 'sum_ratio': 16.02958983071929}, 163: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 164: {'instances': 24, 'min_ratio': 0.38047138047138046, 'sum_ratio': 12.228156577691049}, 165: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 166: {'instances': 18, 'min_ratio': 0.3306355629611997, 'sum_ratio': 8.783049811741062}, 167: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 168: {'instances': 24, 'min_ratio': 0.41587967820916405, 'sum_ratio': 11.737209549341436}, 169: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 170: {'instances': 14, 'min_ratio': 0.41016675632060245, 'sum_ratio': 7.269443073024023}, 171: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 172: {'instances': 26, 'min_ratio': 0.42782969885773625, 'sum_ratio': 13.065797848079665}, 173: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 174: {'instances': 29, 'min_ratio': 0.38095238095238093, 'sum_ratio': 14.228924135698911}, 175: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 176: {'instances': 21, 'min_ratio': 0.4348319709355132, 'sum_ratio': 10.339939764764788}, 177: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 178: {'instances': 28, 'min_ratio': 0.42011661807580175, 'sum_ratio': 13.922009468482697}, 179: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 180: {'instances': 27, 'min_ratio': 0.40439723320158105, 'sum_ratio': 13.729001058311605}, 181: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 182: {'instances': 27, 'min_ratio': 0.3900536323744515, 'sum_ratio': 13.006653531477403}, 183: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 184: {'instances': 26, 'min_ratio': 0.34813170551239364, 'sum_ratio': 12.573844689270429}, 185: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 186: {'instances': 23, 'min_ratio': 0.3730690760711163, 'sum_ratio': 10.694800542940952}, 187: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 188: {'instances': 20, 'min_ratio': 0.38231552162849874, 'sum_ratio': 9.251867127462193}, 189: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 190: {'instances': 28, 'min_ratio': 0.38459841129744043, 'sum_ratio': 13.494972432520855}, 191: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 192: {'instances': 25, 'min_ratio': 0.3618479221927498, 'sum_ratio': 11.646101385264645}, 193: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 194: {'instances': 26, 'min_ratio': 0.35284320723292883, 'sum_ratio': 11.842206602024197}, 195: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 196: {'instances': 18, 'min_ratio': 0.36686802973977695, 'sum_ratio': 8.058442549484889}, 197: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 198: {'instances': 21, 'min_ratio': 0.3872226787181594, 'sum_ratio': 9.834346598960835}, 199: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 200: {'instances': 20, 'min_ratio': 0.3694362017804154, 'sum_ratio': 8.881951072024243}, 201: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 202: {'instances': 17, 'min_ratio': 0.3848221670802316, 'sum_ratio': 8.185826349298727}, 203: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 204: {'instances': 13, 'min_ratio': 0.36984262016163333, 'sum_ratio': 5.720218837686585}, 205: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 206: {'instances': 18, 'min_ratio': 0.3719047619047619, 'sum_ratio': 7.920027018392124}, 207: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 208: {'instances': 26, 'min_ratio': 0.34454638124362896, 'sum_ratio': 11.380070801801955}, 209: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 210: {'instances': 14, 'min_ratio': 0.36927460004383084, 'sum_ratio': 6.017178479298369}, 211: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 212: {'instances': 26, 'min_ratio': 0.31922837585563163, 'sum_ratio': 11.472657465629078}, 213: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 214: {'instances': 21, 'min_ratio': 0.37895114942528735, 'sum_ratio': 9.611105532053562}, 215: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 216: {'instances': 23, 'min_ratio': 0.34986747444149946, 'sum_ratio': 10.051443122735858}, 217: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 218: {'instances': 27, 'min_ratio': 0.3245386389850058, 'sum_ratio': 11.413075641141328}, 219: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 220: {'instances': 18, 'min_ratio': 0.3384137736381598, 'sum_ratio': 8.059782933932535}, 221: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 222: {'instances': 21, 'min_ratio': 0.33976833976833976, 'sum_ratio': 8.938996849675457}, 223: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 224: {'instances': 20, 'min_ratio': 0.35071016076166694, 'sum_ratio': 8.946378926558145}, 225: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 226: {'instances': 21, 'min_ratio': 0.3449251247920133, 'sum_ratio': 9.063712118995657}, 227: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 228: {'instances': 25, 'min_ratio': 0.32806513409961685, 'sum_ratio': 10.556914401247738}, 229: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 230: {'instances': 21, 'min_ratio': 0.35451624419850053, 'sum_ratio': 8.905361844024233}, 231: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 232: {'instances': 16, 'min_ratio': 0.3569455727051178, 'sum_ratio': 7.096273157497324}, 233: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 234: {'instances': 21, 'min_ratio': 0.2909698996655518, 'sum_ratio': 8.65837178176431}, 235: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 236: {'instances': 22, 'min_ratio': 0.32322357019064124, 'sum_ratio': 9.2709472016304}, 237: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 238: {'instances': 25, 'min_ratio': 0.33449530160654745, 'sum_ratio': 10.570661648393374}, 239: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 240: {'instances': 27, 'min_ratio': 0.33121207636525085, 'sum_ratio': 11.177009587214146}, 241: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 242: {'instances': 20, 'min_ratio': 0.3002385211687537, 'sum_ratio': 8.278732939485604}, 243: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 244: {'instances': 22, 'min_ratio': 0.35360427172945713, 'sum_ratio': 9.061502194261088}, 245: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 246: {'instances': 20, 'min_ratio': 0.314540059347181, 'sum_ratio': 8.144577682625835}, 247: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 248: {'instances': 21, 'min_ratio': 0.341762828382028, 'sum_ratio': 8.265349669903818}, 249: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 250: {'instances': 26, 'min_ratio': 0.33964945523448603, 'sum_ratio': 10.897892727925278}, 251: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 252: {'instances': 29, 'min_ratio': 0.3334021896302417, 'sum_ratio': 11.638937243856246}, 253: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 254: {'instances': 24, 'min_ratio': 0.3316493313521545, 'sum_ratio': 9.500118057918574}, 255: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 256: {'instances': 12, 'min_ratio': 0.3334052188915247, 'sum_ratio': 4.771163550323959}, 257: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 258: {'instances': 21, 'min_ratio': 0.31745813889651386, 'sum_ratio': 8.410009033697097}, 259: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 260: {'instances': 18, 'min_ratio': 0.32401830884124305, 'sum_ratio': 7.045307946938208}, 261: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 262: {'instances': 18, 'min_ratio': 0.35846397745288006, 'sum_ratio': 7.3627253663431595}, 263: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 264: {'instances': 28, 'min_ratio': 0.30775618667995347, 'sum_ratio': 11.059032661473054}, 265: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 266: {'instances': 22, 'min_ratio': 0.3422261935154455, 'sum_ratio': 8.604222600736623}, 267: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 268: {'instances': 28, 'min_ratio': 0.31910591935302707, 'sum_ratio': 11.375839730589025}, 269: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 270: {'instances': 23, 'min_ratio': 0.33755274261603374, 'sum_ratio': 9.060032580332265}, 271: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 272: {'instances': 27, 'min_ratio': 0.3205900430239705, 'sum_ratio': 10.418386994929365}, 273: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 274: {'instances': 29, 'min_ratio': 0.3219448094612352, 'sum_ratio': 11.288520305923019}, 275: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 276: {'instances': 15, 'min_ratio': 0.3273718924403856, 'sum_ratio': 5.867585496557412}, 277: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 278: {'instances': 24, 'min_ratio': 0.2673686282227908, 'sum_ratio': 8.964985169911362}, 279: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 280: {'instances': 26, 'min_ratio': 0.3202515177797051, 'sum_ratio': 10.092736904298441}, 281: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 282: {'instances': 16, 'min_ratio': 0.32552750335406755, 'sum_ratio': 6.142911242151006}, 283: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 284: {'instances': 26, 'min_ratio': 0.3191140278917145, 'sum_ratio': 9.981436898925587}, 285: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 286: {'instances': 19, 'min_ratio': 0.3257374351183694, 'sum_ratio': 7.162580063103361}, 287: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 288: {'instances': 25, 'min_ratio': 0.3303063457330416, 'sum_ratio': 9.72795034863203}, 289: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 290: {'instances': 27, 'min_ratio': 0.29811629811629814, 'sum_ratio': 10.097921423412425}, 291: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 292: {'instances': 21, 'min_ratio': 0.3069507864028412, 'sum_ratio': 7.980228360205023}, 293: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 294: {'instances': 20, 'min_ratio': 0.28917564054957295, 'sum_ratio': 7.699126979254785}, 295: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 296: {'instances': 21, 'min_ratio': 0.29797809604043807, 'sum_ratio': 7.6862071037153665}, 297: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 298: {'instances': 20, 'min_ratio': 0.3076295389636883, 'sum_ratio': 7.606115987113972}, 299: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 300: {'instances': 18, 'min_ratio': 0.31781567109530284, 'sum_ratio': 6.386137924991876}, 301: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 302: {'instances': 20, 'min_ratio': 0.29472122635678083, 'sum_ratio': 7.478286819874377}, 303: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 304: {'instances': 20, 'min_ratio': 0.30475049030289825, 'sum_ratio': 7.238163795374676}, 305: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 306: {'instances': 27, 'min_ratio': 0.30077276020284954, 'sum_ratio': 10.20894104712445}, 307: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 308: {'instances': 24, 'min_ratio': 0.3177476118652589, 'sum_ratio': 8.943383355899641}, 309: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 310: {'instances': 20, 'min_ratio': 0.3367252543940796, 'sum_ratio': 7.728999016537984}, 311: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 312: {'instances': 18, 'min_ratio': 0.2794407753666695, 'sum_ratio': 6.535657207889853}, 313: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 314: {'instances': 28, 'min_ratio': 0.2703917790622993, 'sum_ratio': 9.975757068593467}, 315: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 316: {'instances': 18, 'min_ratio': 0.2949912638322656, 'sum_ratio': 6.541085698273153}, 317: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 318: {'instances': 22, 'min_ratio': 0.30250719276613236, 'sum_ratio': 8.049572798845082}, 319: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 320: {'instances': 15, 'min_ratio': 0.31612712198973547, 'sum_ratio': 5.468257124864098}, 321: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 322: {'instances': 24, 'min_ratio': 0.31113201094391246, 'sum_ratio': 8.906888309793032}, 323: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 324: {'instances': 20, 'min_ratio': 0.3011013215859031, 'sum_ratio': 7.331998651792749}, 325: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 326: {'instances': 25, 'min_ratio': 0.28957326045827203, 'sum_ratio': 8.921887076269524}, 327: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 328: {'instances': 21, 'min_ratio': 0.2999663809043537, 'sum_ratio': 7.736733721213398}, 329: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 330: {'instances': 19, 'min_ratio': 0.28938134810710986, 'sum_ratio': 6.71764604380516}, 331: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 332: {'instances': 17, 'min_ratio': 0.2948986722571628, 'sum_ratio': 5.99289238947189}, 333: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 334: {'instances': 15, 'min_ratio': 0.29918290383406665, 'sum_ratio': 5.269448105722168}, 335: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 336: {'instances': 11, 'min_ratio': 0.28900065963060684, 'sum_ratio': 3.7455462018072807}, 337: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 338: {'instances': 15, 'min_ratio': 0.2932716629327166, 'sum_ratio': 5.266949858270531}, 339: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 340: {'instances': 20, 'min_ratio': 0.30084033613445377, 'sum_ratio': 7.054946927007805}, 341: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 342: {'instances': 19, 'min_ratio': 0.29098815692079943, 'sum_ratio': 6.81041043642265}, 343: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 344: {'instances': 24, 'min_ratio': 0.2853648006907469, 'sum_ratio': 8.679422877794353}, 345: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 346: {'instances': 17, 'min_ratio': 0.25635410445285023, 'sum_ratio': 5.740781512655794}, 347: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 348: {'instances': 18, 'min_ratio': 0.2802495067150404, 'sum_ratio': 6.328324112245138}, 349: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 350: {'instances': 18, 'min_ratio': 0.29529988922297834, 'sum_ratio': 6.053435190782609}, 351: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 352: {'instances': 15, 'min_ratio': 0.2838525111252384, 'sum_ratio': 5.16415983585944}, 353: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 354: {'instances': 16, 'min_ratio': 0.3114949848750199, 'sum_ratio': 5.491723751643739}, 355: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 356: {'instances': 18, 'min_ratio': 0.2687134502923977, 'sum_ratio': 6.222064589687958}, 357: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 358: {'instances': 19, 'min_ratio': 0.31757420134430936, 'sum_ratio': 6.631169814104916}, 359: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 360: {'instances': 10, 'min_ratio': 0.31145772022758483, 'sum_ratio': 3.383880313625217}, 361: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 362: {'instances': 14, 'min_ratio': 0.31848430282627416, 'sum_ratio': 4.939385209777894}, 363: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 364: {'instances': 11, 'min_ratio': 0.28678397603893674, 'sum_ratio': 3.791693019362045}, 365: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 366: {'instances': 11, 'min_ratio': 0.29195354336184715, 'sum_ratio': 3.676669544250883}, 367: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 368: {'instances': 15, 'min_ratio': 0.29044684129429893, 'sum_ratio': 5.117289738322259}, 369: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 370: {'instances': 14, 'min_ratio': 0.2956783164223976, 'sum_ratio': 4.871203146686548}, 371: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 372: {'instances': 17, 'min_ratio': 0.2662034263807356, 'sum_ratio': 5.665293329595407}, 373: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 374: {'instances': 19, 'min_ratio': 0.29287305122494434, 'sum_ratio': 6.336151331268094}, 375: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 376: {'instances': 21, 'min_ratio': 0.27258182787814145, 'sum_ratio': 7.084031642109023}, 377: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 378: {'instances': 21, 'min_ratio': 0.2862798020692758, 'sum_ratio': 7.160948146044008}, 379: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 380: {'instances': 12, 'min_ratio': 0.3079881656804734, 'sum_ratio': 4.01215088888793}, 381: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 382: {'instances': 12, 'min_ratio': 0.3008250311332503, 'sum_ratio': 4.197117385017788}, 383: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 384: {'instances': 15, 'min_ratio': 0.26667502507522567, 'sum_ratio': 5.059826288263496}, 385: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 386: {'instances': 11, 'min_ratio': 0.267675483214649, 'sum_ratio': 3.6332661385508125}, 387: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 388: {'instances': 14, 'min_ratio': 0.27766280353200884, 'sum_ratio': 4.722164392784496}, 389: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 390: {'instances': 8, 'min_ratio': 0.27294383896134833, 'sum_ratio': 2.6845556836143896}, 391: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 392: {'instances': 14, 'min_ratio': 0.2936755270394134, 'sum_ratio': 4.767958348162049}, 393: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 394: {'instances': 10, 'min_ratio': 0.2889779559118236, 'sum_ratio': 3.172646115899435}, 395: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 396: {'instances': 17, 'min_ratio': 0.28075353218210364, 'sum_ratio': 5.456341150755396}, 397: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 398: {'instances': 10, 'min_ratio': 0.2977681861248552, 'sum_ratio': 3.178459264616522}, 399: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 400: {'instances': 8, 'min_ratio': 0.3079037228283501, 'sum_ratio': 2.7345544450213444}, 401: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 402: {'instances': 14, 'min_ratio': 0.2819431967383042, 'sum_ratio': 4.719930771016653}, 403: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 404: {'instances': 12, 'min_ratio': 0.27368702392088734, 'sum_ratio': 4.0867055044526746}, 405: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 406: {'instances': 8, 'min_ratio': 0.2797764081983661, 'sum_ratio': 2.5967186354611576}, 407: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 408: {'instances': 8, 'min_ratio': 0.2740811153358682, 'sum_ratio': 2.4747453229562355}, 409: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 410: {'instances': 10, 'min_ratio': 0.2410828025477707, 'sum_ratio': 3.210507632857456}, 411: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 412: {'instances': 11, 'min_ratio': 0.2592029398720142, 'sum_ratio': 3.483120226810106}, 413: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 414: {'instances': 6, 'min_ratio': 0.3066482233941385, 'sum_ratio': 2.0337933763360474}, 415: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 416: {'instances': 4, 'min_ratio': 0.30661213360599865, 'sum_ratio': 1.265523895349222}, 417: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 418: {'instances': 9, 'min_ratio': 0.29435535599743423, 'sum_ratio': 2.938946522602019}, 419: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 420: {'instances': 10, 'min_ratio': 0.29455365775056397, 'sum_ratio': 3.2721167490257006}, 421: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 422: {'instances': 4, 'min_ratio': 0.29282706154055155, 'sum_ratio': 1.1975344281667948}, 423: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 424: {'instances': 4, 'min_ratio': 0.2886181053539656, 'sum_ratio': 1.2985060174664063}, 425: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 426: {'instances': 4, 'min_ratio': 0.30609687323767154, 'sum_ratio': 1.2976228251144173}, 427: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 428: {'instances': 7, 'min_ratio': 0.30100950118764846, 'sum_ratio': 2.3335993626480245}, 429: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 430: {'instances': 5, 'min_ratio': 0.30119991864958306, 'sum_ratio': 1.7144296750600194}, 431: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 432: {'instances': 2, 'min_ratio': 0.2833641649048626, 'sum_ratio': 0.6796000243502525}, 433: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 434: {'instances': 9, 'min_ratio': 0.27347631164425057, 'sum_ratio': 2.883536542017965}, 435: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 436: {'instances': 4, 'min_ratio': 0.2901571546732837, 'sum_ratio': 1.3096433878030762}, 437: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 438: {'instances': 4, 'min_ratio': 0.2765544041450777, 'sum_ratio': 1.238703847571327}, 439: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 440: {'instances': 3, 'min_ratio': 0.3075013068478829, 'sum_ratio': 1.0062969995605422}, 441: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 442: {'instances': 7, 'min_ratio': 0.2782874617737003, 'sum_ratio': 2.2220239254506784}, 443: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 444: {'instances': 6, 'min_ratio': 0.2655959729130461, 'sum_ratio': 1.8289175587618611}, 445: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 446: {'instances': 4, 'min_ratio': 0.2764353801817779, 'sum_ratio': 1.2405980087073745}, 447: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 448: {'instances': 3, 'min_ratio': 0.3123554184708464, 'sum_ratio': 1.0270947232231509}, 449: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 450: {'instances': 5, 'min_ratio': 0.2707317073170732, 'sum_ratio': 1.505760224536485}, 451: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 452: {'instances': 2, 'min_ratio': 0.3165918766540099, 'sum_ratio': 0.6584344556099909}, 453: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 454: {'instances': 1, 'min_ratio': 0.31466124237208576, 'sum_ratio': 0.31466124237208576}, 455: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 456: {'instances': 2, 'min_ratio': 0.3079837431976304, 'sum_ratio': 0.6401989497222291}, 457: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 458: {'instances': 2, 'min_ratio': 0.304554537311376, 'sum_ratio': 0.6634845784636394}, 459: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 460: {'instances': 4, 'min_ratio': 0.2591717839710282, 'sum_ratio': 1.246142606397978}, 461: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 462: {'instances': 3, 'min_ratio': 0.2765652650206455, 'sum_ratio': 0.9085530013026495}, 463: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 464: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 465: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 466: {'instances': 3, 'min_ratio': 0.3069566642985955, 'sum_ratio': 0.9475481375110011}, 467: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 468: {'instances': 1, 'min_ratio': 0.3263572316618317, 'sum_ratio': 0.3263572316618317}, 469: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 470: {'instances': 1, 'min_ratio': 0.3903572730586949, 'sum_ratio': 0.3903572730586949}, 471: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 472: {'instances': 2, 'min_ratio': 0.31346050349817617, 'sum_ratio': 0.6559336633035364}, 473: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 474: {'instances': 1, 'min_ratio': 0.30813475760065734, 'sum_ratio': 0.30813475760065734}, 475: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 476: {'instances': 2, 'min_ratio': 0.32078494193031637, 'sum_ratio': 0.6563786730936678}, 477: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 478: {'instances': 2, 'min_ratio': 0.3282260548198337, 'sum_ratio': 0.6711816372763008}, 479: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 480: {'instances': 2, 'min_ratio': 0.28168234643054785, 'sum_ratio': 0.631568516037833}, 481: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 482: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 483: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 484: {'instances': 2, 'min_ratio': 0.35193452380952384, 'sum_ratio': 0.7168874564670185}, 485: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 486: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 487: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 488: {'instances': 1, 'min_ratio': 0.32471975542291454, 'sum_ratio': 0.32471975542291454}, 489: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 490: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 491: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 492: {'instances': 1, 'min_ratio': 0.3359580052493438, 'sum_ratio': 0.3359580052493438}, 493: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 494: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 495: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 496: {'instances': 1, 'min_ratio': 0.32435491172476233, 'sum_ratio': 0.32435491172476233}, 497: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 498: {'instances': 1, 'min_ratio': 0.33176912247771, 'sum_ratio': 0.33176912247771}, 499: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 500: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 501: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 502: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 503: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 504: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 505: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 506: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 507: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 508: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 509: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 510: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 511: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 512: {'instances': 1, 'min_ratio': 0.33222836095764274, 'sum_ratio': 0.33222836095764274}, 513: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 514: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 515: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 516: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 517: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 518: {'instances': 2, 'min_ratio': 0.28769587653268947, 'sum_ratio': 0.6040019913257368}, 519: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 520: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 521: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 522: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 523: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 524: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 525: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 526: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 527: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 528: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 529: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 530: {'instances': 1, 'min_ratio': 0.2973724884080371, 'sum_ratio': 0.2973724884080371}, 531: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 532: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 533: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 534: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 535: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 536: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 537: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 538: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 539: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 540: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 541: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 542: {'instances': 1, 'min_ratio': 0.274580223880597, 'sum_ratio': 0.274580223880597}, 543: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 544: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 545: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 546: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 547: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 548: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 549: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 550: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 551: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 552: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 553: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 554: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 555: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 556: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 557: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 558: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 559: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 560: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 561: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 562: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 563: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 564: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 565: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 566: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 567: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 568: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 569: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 570: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 571: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 572: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 573: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 574: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 575: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 576: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 577: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 578: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 579: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 580: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 581: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 582: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 583: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 584: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 585: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 586: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 587: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 588: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 589: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 590: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 591: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 592: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 593: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 594: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 595: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 596: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 597: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 598: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 599: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 600: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 601: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 602: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 603: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 604: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 605: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 606: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 607: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 608: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 609: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 610: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 611: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 612: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 613: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 614: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 615: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 616: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 617: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 618: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 619: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 620: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 621: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 622: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 623: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 624: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 625: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 626: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 627: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 628: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 629: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 630: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 631: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 632: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 633: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 634: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 635: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 636: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 637: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 638: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 639: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 640: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 641: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 642: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 643: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 644: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 645: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 646: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 647: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 648: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 649: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 650: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 651: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 652: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 653: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 654: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 655: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 656: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 657: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 658: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 659: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 660: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 661: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 662: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 663: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 664: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 665: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 666: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 667: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 668: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 669: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 670: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 671: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 672: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 673: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 674: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 675: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 676: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 677: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 678: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 679: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 680: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 681: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 682: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 683: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 684: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 685: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 686: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 687: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 688: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 689: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 690: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 691: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 692: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 693: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 694: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 695: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 696: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 697: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 698: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 699: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 700: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 701: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 702: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 703: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 704: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 705: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 706: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 707: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 708: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 709: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 710: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 711: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 712: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 713: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 714: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 715: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 716: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 717: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 718: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 719: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 720: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 721: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 722: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 723: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 724: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 725: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 726: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 727: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 728: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 729: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 730: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 731: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 732: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 733: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 734: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 735: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 736: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 737: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 738: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 739: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 740: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 741: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 742: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 743: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 744: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 745: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 746: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 747: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 748: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 749: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 750: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 751: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 752: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 753: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 754: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 755: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 756: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 757: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 758: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 759: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 760: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 761: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 762: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 763: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 764: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 765: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 766: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 767: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 768: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 769: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 770: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 771: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 772: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 773: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 774: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 775: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 776: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 777: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 778: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 779: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 780: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 781: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 782: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 783: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 784: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 785: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 786: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 787: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 788: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 789: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 790: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 791: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 792: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 793: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 794: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 795: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 796: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 797: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 798: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 799: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 800: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 801: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 802: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 803: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 804: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 805: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 806: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 807: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 808: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 809: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 810: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 811: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 812: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 813: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 814: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 815: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 816: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 817: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 818: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 819: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 820: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 821: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 822: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 823: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 824: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 825: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 826: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 827: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 828: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 829: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 830: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 831: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 832: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 833: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 834: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 835: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 836: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 837: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 838: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 839: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 840: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 841: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 842: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 843: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 844: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 845: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 846: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 847: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 848: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 849: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 850: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 851: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 852: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 853: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 854: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 855: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 856: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 857: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 858: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 859: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 860: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 861: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 862: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 863: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 864: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 865: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 866: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 867: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 868: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 869: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 870: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 871: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 872: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 873: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 874: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 875: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 876: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 877: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 878: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 879: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 880: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 881: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 882: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 883: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 884: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 885: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 886: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 887: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 888: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 889: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 890: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 891: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 892: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 893: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 894: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 895: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 896: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 897: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 898: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 899: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 900: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 901: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 902: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 903: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 904: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 905: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 906: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 907: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 908: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 909: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 910: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 911: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 912: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 913: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 914: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 915: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 916: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 917: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 918: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 919: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 920: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 921: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 922: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 923: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 924: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 925: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 926: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 927: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 928: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 929: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 930: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 931: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 932: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 933: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 934: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 935: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 936: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 937: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 938: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 939: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 940: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 941: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 942: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 943: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 944: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 945: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 946: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 947: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 948: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 949: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 950: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 951: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 952: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 953: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 954: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 955: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 956: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 957: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 958: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 959: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 960: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 961: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 962: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 963: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 964: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 965: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 966: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 967: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 968: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 969: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 970: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 971: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 972: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 973: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 974: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 975: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 976: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 977: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 978: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 979: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 980: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 981: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 982: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 983: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 984: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 985: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 986: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 987: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 988: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 989: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 990: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 991: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 992: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 993: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 994: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 995: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 996: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 997: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 998: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 999: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}, 1000: {'instances': 0, 'min_ratio': 1, 'sum_ratio': 0}}
